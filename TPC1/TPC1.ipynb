# %%
import random
def fosf():
    fosforos=21
    inicio=int(input('''Quer jogar em primeiro (1) ou segundo lugar(2)?  '''))
    if inicio!=1 and inicio!=2:
        print("Número inválido, escolha 1 ou 2")
    else:
        while fosforos>1:
            if inicio==1:
                jog=int(input("Escolha o numero de fosforos tirar entre 1 a 4:  "))
                if jog<1 or jog>4:
                    print("Escolha um numero valido, 1,2,3 ou 4!")
                else:
                    comp=5-jog
                    print("Jogador retirou ", jog)
                    print("Computador tirou ", comp)
                    fosforos=fosforos-jog-comp
                    print("Restam",fosforos,"fosforos")
                if fosforos==1:
                    print("O computador ganhou!")                                   
        
            else:
                op=[1,2,3,4]
                comp=random.choice(op)
                print("Computador tirou ", comp)
                jog=int(input("Escolha o numero de fosforos tirar entre 1 a 4:  "))
                if jog<1 or jog>4:
                    print("Escolha um numero valido, 1,2,3 ou 4!")
                    jog=int(input("Escolha o numero de fosforos tirar entre 1 a 4:  "))
                
                fosforos=fosforos-jog-comp
                
                
                
                while fosforos>0:
                    if (comp+jog)==5:
                        op=[1,2,3,4]
                        comp=random.choice(op)
                        print("Computador tirou ", comp)
                        jog=int(input("Escolha o numero de fosforos tirar entre 1 a 4:  "))
                    
                        if jog<1 or jog>4:
                            print("Escolha um numero valido, 1,2,3 ou 4!")
                            jog=int(input("Escolha o numero de fosforos tirar entre 1 a 4:  "))
                        else:
                            print("Jogador retirou ", jog)
                            fosforos=fosforos-jog-comp
                            print("Restam",fosforos,"fosforos")
                            if fosforos==1:
                                print("O jogador ganhou!!!")
                            
            
                    
                    elif (comp+jog)<5:
                        comp=5-comp-jog   
                        print("Computador tirou ", comp)
                        if fosforos-comp==1:
                            print("O computador ganhou!")
                        else:
                            jog=int(input("Escolha o numero de fosforos tirar entre 1 a 4:  "))
                            if jog<1 or jog>4:
                                print("Escolha um numero valido, 1,2,3 ou 4!")
                                jog=int(input("Escolha o numero de fosforos tirar entre 1 a 4:  "))
                            else:
                                print("Jogador retirou ", jog)
                                fosforos=fosforos-jog-comp
                                print("Restam",fosforos,"fosforos")
                                if fosforos==1:
                                     print("O jogador ganhou!!!")
                            
                        break
                    
                    else:
                        comp=10-comp-jog
                        print("Computador tirou ", comp)
                        if fosforos-comp==1:
                            print("O computador ganhou!")
                        else:
                            jog=int(input("Escolha o numero de fosforos tirar entre 1 a 4:  "))
                            if jog<1 or jog>4:
                                print("Escolha um numero valido, 1,2,3 ou 4!")
                                jog=int(input("Escolha o numero de fosforos tirar entre 1 a 4:  "))
                            else:
                                print("Jogador retirou ", jog)
                                fosforos=fosforos-jog-comp
                                print("Restam",fosforos,"fosforos")
                                if fosforos==1:
                                     print("O jogador ganhou!!!")
                            
                            
                        break
                    
                    
                    if fosforos==1:
                        break
                        
              
fosf()
